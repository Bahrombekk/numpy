# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/numpy/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Iris_Dataset_Homework_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %% [markdown]
# ## About Iris Dataset
#
# Ma'lumotlar to'plami Irisning uchta turidan (Iris setosa, Iris virginica va Iris versicolor) har biridan 50 ta namunadan iborat.
#
# Har bir namunadan to'rtta xususiyat o'lchandi: sepals va gulbarglarning uzunligi va kengligi, santimetrda. Ushbu to'rt xususiyatning kombinatsiyasiga asoslanib, Fisher turlarni bir-biridan farqlash uchun chiziqli diskriminant modelini ishlab chiqdi.

# %%
# !wget https://raw.githubusercontent.com/JavohirJalilov/Classification/master/Iris.csv
# Out:
# --2023-04-07 03:43:27--  https://raw.githubusercontent.com/JavohirJalilov/Classification/master/Iris.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5107 (5.0K) [text/plain]
# Saving to: ‘Iris.csv.1’
#
# Iris.csv.1          100%[===================>]   4.99K  --.-KB/s    in 0s
#
# 2023-04-07 03:43:27 (47.7 MB/s) - ‘Iris.csv.1’ saved [5107/5107]

# %% [markdown]
# ##About Task
# - **read_csv_data** funksiya yarating va csv datasetni qar bir qatorni list ko'rinishida qaytaring.
# - **get_class_one_hot** funksiya yarating. Dataset 3 ta classni 0, 1, 2 ga o'zgartirib list ko'rinishida qaytaring.
# - **get_data_labels** sepal_Length, sepal_Width, petal_Length, petal_Width labellarni alohida list ko'rinishida qaytaring.
# - **plot_data** ma'lumotlarni tasvirlang. Har ikkita label bilan scatter plot chizing, quiydagi rasmda keltirilgan.

# %%
def read_csv_data(file_path:str)->list:
  """
  Read csv file
  Args:
      file_path(str): file path
  Returns:
      list: data split row
  """
  data=open(file_path)
  data=csv.reader(data)
  return list(data)
  # WRITE YOUR CODE HERE

# %%
data=read_csv_data('Iris.csv')

# %%
print(data[1])
# Out:
# ['1', '5.1', '3.5', '1.4', '0.2', 'Iris-setosa']

# %%
def get_class_one_hot(dataset:list,class_name:list)->list:
  """
  Change the three classes to a number view.
  Args:
    dataset(list): split row
    class_name(list): 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'
  Returns:
    list: return list
  """
  dataset_class = []
  for i in data:
    dataset_class.append(i[5])

  # WRITE YOUR CODE HERE

  return dataset_class

# %%
from os import sep
def get_data_labels(dataset:list)->list:
  """
  Read csv file
  Args:
    dataset(list): split row
  Returns:
    list: sepal_Length, sepal_Width, petal_Length, petal_Width
  """
  sepal_Length, sepal_Width, petal_Length, petal_Width = [], [], [], []
  for i in data:
    sepal_Length.append(i[1])
    sepal_Width.append(i[2])
    petal_Length.append(i[3])
    petal_Width.append(i[4])

  
  # WRITE YOUR CODE HERE
  return sepal_Length,sepal_Width,petal_Length,petal_Width
  plt.show()
file_path='Iris.csv'
data = read_csv_data(file_path)

sepal_Length,sepal_Width,petal_Length,petal_Width = get_data_labels(data)

# %%
data = get_data_labels(data[1:])

# %%
plt.scatter(sepal_Length,sepal_Width)
plt.scatter(petal_Length,petal_Width)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,3,1)
plt.scatter(sepal_Length,sepal_Width)
plt.subplot(2,3,2)
plt.scatter(sepal_Length,petal_Length)
plt.subplot(2,3,3)
plt.scatter(sepal_Length,petal_Width)
plt.subplot(2,3,4)
plt.scatter(sepal_Width,petal_Length)
plt.subplot(2,3,5)
plt.scatter(sepal_Width,petal_Width)
plt.subplot(2,3,6)
plt.scatter(petal_Length,petal_Width)
plt.show()

# %%
dataset = read_csv_data("Iris.csv")
class_name = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']

dataset_class = get_class_one_hot(dataset, class_name)
labels = get_data_labels(dataset)

# %%
def plot_data(dataset_class, labels):
  sepal_Length, sepal_Width, petal_Length, petal_Width = labels
  # WRITE YOUR CODE HERE
  
  plt.show()

# %%
plot_data(dataset_class, labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-c8b737eb8256> in <cell line: 1>()
# ----> 1 plot_data(dataset_class, labels)
#
# <ipython-input-18-3edcf4ef3fcf> in plot_data(dataset_class, labels)
#       1 def plot_data(dataset_class, labels):
# ----> 2   sepal_Length, sepal_Width, petal_Length, petal_Width = labels
#       3   # WRITE YOUR CODE HERE
#       4   plt.show()
#
# TypeError: cannot unpack non-iterable NoneType object
